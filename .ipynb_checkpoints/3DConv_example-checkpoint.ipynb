# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   #if like me you do not have a lot of memory in your GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "" #then these two lines force keras to use your CPU
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, Dropout, BatchNormalization
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
import h5py
from plot3D import *

# %%
def array_to_color(array, cmap="Oranges"):
    s_m = plt.cm.ScalarMappable(cmap=cmap)
    return s_m.to_rgba(array)[:,:-1]


def rgb_data_transform(data):
    data_t = []
    for i in range(data.shape[0]):
        data_t.append(array_to_color(data[i]).reshape(16, 16, 16, 3))
    return np.asarray(data_t, dtype=np.float32)

# %%
with h5py.File("./train_point_clouds.h5", "r") as hf:    
    a = hf["0"]
    b = a['img'][:]
    s = a['points'][:]

# %%
plt.imshow(b)
plt.title('The figure 5 in 2d')
# Out:
# Text(0.5, 1.0, 'The figure 5 in 2d')

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(s[:,0], s[:,1], zs=s[:,2])
ax.view_init(10, 0)
plt.title('The figure 5 in 3d Cloud point')
# Out:
# Text(0.5, 0.92, 'The figure 5 in 3d Cloud point')

# %%
s[:,0]
# Out:
# array([0.15, 0.15, 0.15, ..., 0.15, 0.15, 0.15])

# %%
with h5py.File("./full_dataset_vectors.h5", "r") as hf:    

    # Split the data into training/test features/targets
    X_train = hf["X_train"][:]
    targets_train = hf["y_train"][:]
    X_test = hf["X_test"][:] 
    targets_test = hf["y_test"][:]

    # Determine sample shape
    sample_shape = (16, 16, 16, 3)

    # Reshape data into 3D format
    X_train = rgb_data_transform(X_train)
    X_test = rgb_data_transform(X_test)

    # Convert target vectors to categorical targets
    targets_train = to_categorical(targets_train).astype(np.integer)
    targets_test = to_categorical(targets_test).astype(np.integer)

# %%
X_train.shape
# Out:
# (10000, 16, 16, 16, 3)

# %%
# Create the model
model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=sample_shape))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(0.5))
model.add(Conv3D(64, kernel_size=(3, 3, 3), activation='relu', kernel_initializer='he_uniform'))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization(center=True, scale=True))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(256, activation='relu', kernel_initializer='he_uniform'))
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=keras.optimizers.Adam(lr=0.001),
              metrics=['accuracy'])
model.summary()
# Fit data to model
history = model.fit(X_train, targets_train,
            batch_size=128,
            epochs=40,
            verbose=1,
            validation_split=0.3)

# Generate generalization metrics
score = model.evaluate(X_test, targets_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# Plot history: Categorical crossentropy & Accuracy
plt.plot(history.history['loss'], label='Categorical crossentropy (training data)')
plt.plot(history.history['val_loss'], label='Categorical crossentropy (validation data)')
plt.plot(history.history['acc'], label='Accuracy (training data)')
plt.plot(history.history['val_acc'], label='Accuracy (validation data)')
plt.title('Model performance for 3D MNIST Keras Conv3D example')
plt.ylabel('Loss value')
plt.xlabel('No. epoch')
plt.legend(loc="upper left")
plt.show()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_5 (Conv3D)            (None, 14, 14, 14, 32)    2624
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 7, 7, 7, 32)       0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 7, 32)       128
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 7, 7, 7, 32)       0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 5, 5, 5, 64)       55360
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 2, 2, 2, 64)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 2, 2, 2, 64)       256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 2, 64)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 258,058
# Trainable params: 257,866
# Non-trainable params: 192
# _________________________________________________________________
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 2.3676 - acc: 0.2370 - val_loss: 2.2420 - val_acc: 0.2550
# Epoch 2/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.7167 - acc: 0.4010 - val_loss: 3.1162 - val_acc: 0.1757
# Epoch 3/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.5015 - acc: 0.4719 - val_loss: 2.8639 - val_acc: 0.2753
# Epoch 4/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.3902 - acc: 0.5133 - val_loss: 2.1104 - val_acc: 0.2743
# Epoch 5/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.3139 - acc: 0.5340 - val_loss: 2.1778 - val_acc: 0.3483
# Epoch 6/40
# 7000/7000 [==============================] - 57s 8ms/step - loss: 1.2671 - acc: 0.5517 - val_loss: 1.5701 - val_acc: 0.4980
# Epoch 7/40
# 7000/7000 [==============================] - 57s 8ms/step - loss: 1.2165 - acc: 0.5714 - val_loss: 1.8289 - val_acc: 0.4337
# Epoch 8/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.1817 - acc: 0.5841 - val_loss: 2.2599 - val_acc: 0.3767
# Epoch 9/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.1384 - acc: 0.5897 - val_loss: 1.1648 - val_acc: 0.6040
# Epoch 10/40
# 7000/7000 [==============================] - 59s 8ms/step - loss: 1.1138 - acc: 0.6080 - val_loss: 3.9893 - val_acc: 0.3127
# Epoch 11/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.1113 - acc: 0.6054 - val_loss: 2.4966 - val_acc: 0.3363
# Epoch 12/40
# 7000/7000 [==============================] - 57s 8ms/step - loss: 1.0622 - acc: 0.6229 - val_loss: 2.8265 - val_acc: 0.3490
# Epoch 13/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.0361 - acc: 0.6299 - val_loss: 2.4906 - val_acc: 0.2810
# Epoch 14/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.0245 - acc: 0.6359 - val_loss: 2.0394 - val_acc: 0.4407
# Epoch 15/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 1.0037 - acc: 0.6434 - val_loss: 1.9587 - val_acc: 0.4457
# Epoch 16/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.9765 - acc: 0.6504 - val_loss: 1.3614 - val_acc: 0.5417
# Epoch 17/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.9760 - acc: 0.6570 - val_loss: 1.2486 - val_acc: 0.5853
# Epoch 18/40
# 7000/7000 [==============================] - 57s 8ms/step - loss: 0.9651 - acc: 0.6549 - val_loss: 3.0945 - val_acc: 0.2987
# Epoch 19/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.9228 - acc: 0.6730 - val_loss: 4.0645 - val_acc: 0.2487
# Epoch 20/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.9248 - acc: 0.6719 - val_loss: 1.6638 - val_acc: 0.5033
# Epoch 21/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.8943 - acc: 0.6793 - val_loss: 3.4135 - val_acc: 0.3223
# Epoch 22/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.8896 - acc: 0.6784 - val_loss: 1.1511 - val_acc: 0.5993
# Epoch 23/40
# 7000/7000 [==============================] - 59s 8ms/step - loss: 0.8914 - acc: 0.6853 - val_loss: 2.7482 - val_acc: 0.3923
# Epoch 24/40
# 7000/7000 [==============================] - 59s 8ms/step - loss: 0.8520 - acc: 0.6927 - val_loss: 1.3216 - val_acc: 0.5527
# Epoch 25/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.8364 - acc: 0.7050 - val_loss: 1.7432 - val_acc: 0.5393
# Epoch 26/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.8310 - acc: 0.7070 - val_loss: 2.1237 - val_acc: 0.4790
# Epoch 27/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.8218 - acc: 0.7089 - val_loss: 4.6784 - val_acc: 0.3017
# Epoch 28/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7997 - acc: 0.7184 - val_loss: 2.4186 - val_acc: 0.3600
# Epoch 29/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7938 - acc: 0.7173 - val_loss: 3.3102 - val_acc: 0.3877
# Epoch 30/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7841 - acc: 0.7183 - val_loss: 4.4051 - val_acc: 0.3220
# Epoch 31/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7459 - acc: 0.7320 - val_loss: 2.2222 - val_acc: 0.4617
# Epoch 32/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7437 - acc: 0.7351 - val_loss: 1.4211 - val_acc: 0.6347
# Epoch 33/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7270 - acc: 0.7430 - val_loss: 1.1060 - val_acc: 0.6340
# Epoch 34/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7133 - acc: 0.7459 - val_loss: 2.3321 - val_acc: 0.4570
# Epoch 35/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.7115 - acc: 0.7454 - val_loss: 1.5243 - val_acc: 0.5893
# Epoch 36/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.6886 - acc: 0.7636 - val_loss: 4.3696 - val_acc: 0.3290
# Epoch 37/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.6978 - acc: 0.7557 - val_loss: 3.8689 - val_acc: 0.3210
# Epoch 38/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.6670 - acc: 0.7620 - val_loss: 1.7261 - val_acc: 0.4840
# Epoch 39/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.6650 - acc: 0.7657 - val_loss: 6.4489 - val_acc: 0.2697
# Epoch 40/40
# 7000/7000 [==============================] - 58s 8ms/step - loss: 0.6421 - acc: 0.7733 - val_loss: 1.5427 - val_acc: 0.5427
# Test loss: 1.579768424987793 / Test accuracy: 0.5235
